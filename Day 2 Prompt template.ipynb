# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai_chat_models import ChatOpenAI

from langchain_core.prompts.chat import (SystemMessagePromptTemplate,
                                            HumanMessagePromptTemplate,
                                            ChatPromptTemplate)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_openai_chat_models import ChatOpenAI
#       3 from langchain_core.prompts.chat import (SystemMessagePromptTemplate,
#       4                                             HumanMessagePromptTemplate,
#       5                                             ChatPromptTemplate)
#
# ModuleNotFoundError: No module named 'langchain_openai_chat_models'
