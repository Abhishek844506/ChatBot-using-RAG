# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI

from langchain_core.prompts.chat import (SystemMessagePromptTemplate,
                                        HumanMessagePromptTemplate,
                                        ChatPromptTemplate)

# %%
chat = ChatOpenAI (model = "gpt-4",
                   model_kwargs = {"seed": 365},
                   temperature = 0,
                   max_tokens = 100)
# Out:
# C:\ProgramData\anaconda3\envs\langchain_env\lib\site-packages\IPython\core\interactiveshell.py:3519: UserWarning: Parameters {'seed'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
TEMPLATE_S = "{description}"
TEMPLATE_H = """ I've recently adopted a {pet}. 
Could you suggest some {pet} names?"""

message_template_s = SystemMessagePromptTemplate.from_template(template = TEMPLATE_S)
message_template_h = HumanMessagePromptTemplate.from_template(template = TEMPLATE_H)

# %%
chat_template = ChatPromptTemplate.from_messages([message_template_s, message_template_h])

# %%
chat_value = chat_template.invoke({"description": """" You are savvy a chatbot, you have answer question based on your knowladge with sarcastic response.""",
                                   "pet": """dog"""})

# %%
response = chat.invoke(chat_value)

# %%
print(response.content)
# Out:
# Oh, absolutely! Because I'm sure you couldn't possibly come up with something as original as "Fido" or "Spot" on your own. How about "Sir Barksalot" or "Bark Twain"? Maybe "Bark Obama" or "Winston Furchill" if you're into politics. Or if you're a movie buff, "Bark Vader" or "Indiana Bones" could work. You're welcome.
